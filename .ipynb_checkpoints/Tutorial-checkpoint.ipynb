# %% [markdown]
# # Bispec
# A Tool to handle cosmological density fields, perform power spectrum and bispectrum
#
# Contact: cfpark00@gmail.com

# %% [markdown]
# ### Installation:
# -Bispec is fully written in C++
#
# -This tutorial is for the Python wrapper, which just runs the scripts
#
# -To compile the code:
#
# ```
# cd ./src
# make
# ```
#
# -To clean the make:
#
# ```
# cd ./src
# make clean
# ```
# -This notebook will serve as documentation for options for the C++ code

# %%
import numpy as np
import matplotlib.pyplot as plt
import subprocess

# %% [markdown]
# ### BispecPy is the Python wrapper for the compiler C++ code. No computation is done in Python

# %%
import cosgeopy.BispecPy as Bp
# Out:
# Please set BispecPy.exdir="path_to_C++_executables"
# This is "./src/" from the default BispecPy.py location

# %% [markdown]
# ### fullrun
#
# -Makes a Gaussian density field, estimates the power spectrum and optionally make the realspace realisation and the NAIVE(VERY SLOW) bispectrum

# %% [markdown]
# The option only_command prints out the command to run in the terminal to get the same result

# %% [markdown]
# Remember that the command runs in src

# %%
Bp.fullrun(nside=64,realspace=True,doPk=True,doBk=False
                        ,Pkfilename=""
                        ,filenamek="./data/delta_k.dat",filenamePk="./data/pk.dat",filenameBk="./data/bk.dat"
                        ,filenamer="./data/delta.dat"
                        ,quiet=False,n_thread=None,only_command=True)
# Out:
# ./src/fullrun -nside 64 -Pkfilename  -filenamek ./data/delta_k.dat -filenamer ./data/delta.dat -filenamePk ./data/pk.dat -filenameBk ./data/bk.dat -realspace

# %% [markdown]
# Now lets actually run it. Note that doBK is True and the Naive estimator is VERY slow

# %%
Bp.fullrun(nside=64,realspace=True,doPk=True,doBk=True
                        ,Pkfilename=""
                        ,filenamek="./data/delta_k.dat",filenamePk="./data/pk.dat",filenameBk="./data/bk.dat"
                        ,filenamer="./data/delta.dat"
                        ,quiet=False,n_thread=None,only_command=False)
# Out:
# Starting Program
# --------------
#
# nside=64
# filenamek=./data/delta_k.dat
# will also save realspace as filenamer=./data/delta.dat
#  Time: 2.31266e-05
# Start program at: 2.31266e-05 Time: 2.40803e-05
# Start filling at: 4.72069e-05 Time: 0.0109618
# Start delta_k write at: 0.011009 Time: 0.00185418
# Start Pk: 0.0128632 Time: 0.00418901
# Start Bk: 0.0170522 Time: 2.03768
# Start Bk write at: 2.05474 Time: 0.000206947
# Start FFT at: 2.05494 Time: 0.00151515
# Start delta write at: 2.05646 Time: 0.00103092
# Start Closing: 2.05749 Time: 0.00012207
#
# Run successful. 2.05761
# --------------
#
# Total Time: 2.05762

# %% [markdown]
# ### powerspectrum
#
# -Simple Power Spectrum estimator

# %%
Bp.powerspectrum(nside=64,filename="./data/delta_k.dat",only_command=False)
# Out:
# Starting Program
# --------------
#
# nside=64
# From filenamek=./data/delta_k.dat
#  Time: 2.19345e-05
# Start program at: 2.19345e-05 Time: 0.000681877
# Start Pk: 0.000703812 Time: 0.011508
# Start Closing: 0.0122118 Time: 0.000127077
#
# Run successful. 0.0123389
# --------------
#
# Total Time: 0.0123448

# %% [markdown]
# Plot the Powerspectrum

# %%
Bp.plotPk(filename="./data/pk.dat",nside=64,inputPK="default")

# %% [markdown]
# ### bispectrum
#
# -Implements the FFT bispectrum estimator from Jeong, Donghui. (2010). Cosmology with high (z>1) redshift galaxy surveys.

# %%
Bp.bispectrum(nside=64,filename="./data/delta_k.dat"
                    ,filenameBk="./data/bk.dat",filenameBkind="./data/bkinds.dat"
                    ,only_command=False)
# Out:
# Starting Program
# --------------
#
# nside=64
# From filenamek=./data/delta_k.dat
#  Time: 2.38419e-05
# Start program at: 2.38419e-05 Time: 0.000715017
# Start Bk: 0.000738859
#   Generate k-rings
#   FFT k-rings
#   Sum over realspace
#   Done
#  Time: 1.03528
# Make Stat at: 1.03601
#   Computed 6545 triplets in 1.03528. 0.000158178 per triplet
#  Time: 2.81334e-05
# Start Bk write at: 1.03604 Time: 0.00058794
# Start Bkind write at: 1.03663 Time: 0.000232935
#
# Run successful. 1.03686
# --------------
#
# Total Time: 1.03687

# %% [markdown]
# Plot the Bispectrum, this is a binned image

# %%
Bp.plotBk(filenameBk="./data/bk.dat",filenameBkind="./data/bkinds.dat",nside=64)

# %% [markdown]
# It essentially gives zero since we are dealing with a Gaussian field

# %% [markdown]
# Let's repeat with a non-gaussian field. We just make a simple random field

# %%
fieldcustom=1+np.random.random((64,64,64))*0.3
fieldcustom=fieldcustom.astype(np.float64)
fieldcustom.tofile("./data/randomfield.dat")

# %% [markdown]
# Use quiet

# %%
Bp.bispectrum(nside=64,filename="./data/randomfield.dat"
                    ,filenameBk="./data/random_bk.dat"
                    ,filenameBkind="./data/random_bkinds.dat"
                    ,only_command=False,quiet=True)

# %%
Bp.plotBk(filenameBk="./data/random_bk.dat"
                ,filenameBkind="./data/random_bkinds.dat"
                ,nside=64)

# %% [markdown]
# ### memory_estimate
#
# -This Python function estimates the rough memory consumption

# %%
Bp.memory_estimate(nside=256,start=10,step=10)
# Out:
# These are rough estimates for nside=256
#
# fullrun
#   -default: 0.27 GB
#   -realspace: 0.47 GB
# gaussianfield
#   -default: 0.27 GB
#   -realspace: 0.40 GB
# powerspectrum
#   -default: 0.13 GB
# bispectrum for 12.0 ks, thus 364 triplets.
#   -default: 4.97 GB
# bispectrum_naive
#   -default: 0.27 GB

# %% [markdown]
# ### Some more tools for plotting

# %%
Bp.plotrfield(filename="./data/delta.dat",nside=64,z=4)

# %%
Bp.plotkfield(filename="./data/delta_k.dat",nside=64,z=0)
